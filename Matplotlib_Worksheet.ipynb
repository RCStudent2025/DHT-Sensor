# %% [markdown]
# <a href="https://colab.research.google.com/github/RCStudent2025/DHT-Sensor/blob/main/Matplotlib_Worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib Student Worksheet
#
# This worksheet contains **10 hands-on exercises** to practice Matplotlib along with core Python libraries like **NumPy** and **pandas**. Each exercise has:
#
# - A **Markdown cell** describing the task
# - An empty **code cell** with TODOs for you to complete
#
# > Tip: Run the very first code cell to import libraries before starting.

# %%
# 🚀 Run this cell first (libraries + sample data helpers)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Inline plotting for Jupyter
# %matplotlib inline

# Utility: deterministic randomness
rng = np.random.default_rng(42)

print('Libraries ready! NumPy:', np.__version__, '| pandas:', pd.__version__)
# Out:
# Libraries ready! NumPy: 2.0.2 | pandas: 2.2.2

# %% [markdown]
# ## Exercise 1 — First Line Plot
# Create a simple line plot of `x = [0,1,2,3,4]` vs `y = [0,1,4,9,16]`.
#
# **Goals:**
# - Use `plt.plot(x, y)`
# - Add a title and axis labels
# - Call `plt.show()` to display the figure

# %%
# TODO: Make a basic line plot with labels and title
x = [0,1,2,3,4]
y = [0,1,4,9,16]

# Your code here:
plt.plot(x, y, marker = "o")
plt.xlabel("x")
plt.ylabel("y")
plt.title("x against y")
plt.show()

# %% [markdown]
# ## Exercise 2 — Style Your Plot
# Plot the same data as Exercise 1 but:
# - Change line color to `'green'`
# - Use a dashed linestyle (`'--'`)
# - Set linewidth to `3`
#
# **Hint:** `plt.plot(x, y, color='green', linestyle='--', linewidth=3)`

# %%
# TODO: Style the line (color, linestyle, linewidth) and show the plot
x = [0,1,2,3,4]
y = [0,1,4,9,16]

# Your code here
plt.plot(x, y, marker = "o", color = "green", linestyle = "--", linewidth = 3)
plt.show()

# %% [markdown]
# ## Exercise 3 — Multiple Lines & Legend
# Plot two lines on the same axes:
# - `y1 = x`
# - `y2 = x**2`
#
# **Goals:**
# - Plot both lines with different styles
# - Add a legend (use `label=` in `plt.plot` and `plt.legend()`)
# - Add grid lines (`plt.grid(True)`)

# %%
# TODO: Plot two lines with legend and grid
x = np.arange(0, 6)
y1 = x
y2 = x**2

# Your code here
plt.plot(x, y1, label='linear')
plt.plot(x, y2, label='curve')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercise 4 — Scatter Plot & Markers
# Generate 50 random points around a line `y = 2x + 1` with some noise.
#
# **Goals:**
# - Create `x` uniformly in `[0, 10]`
# - Create `y = 2x + 1 + noise` where `noise ~ Normal(0, 2)`
# - Use `plt.scatter` with a marker style of your choice (e.g., `'o'`)
# - Label axes and title

# %%
# TODO: Make a scatter plot with random data and noise
n = 50
x = rng.uniform(0, 10, size=n)
noise = rng.normal(0, 2, size=n)
y = 2*x + 1 + noise

# Your code here
plt.scatter(x, y, marker = "o")
plt.xlabel("x"); plt.ylabel("y")
plt.title("y = 2x + 1 with noise")
plt.show()

# %% [markdown]
# ## Exercise 5 — Bar Chart
# Create a bar chart of daily sales:
#
# Days = `['Mon','Tue','Wed','Thu','Fri']`
# Sales = `[12, 18, 9, 14, 20]`
#
# **Goals:**
# - Use `plt.bar`
# - Rotate x-tick labels by 0 or 45 degrees as you like
# - Add value labels on top of bars (optional)

# %%
# TODO: Create a bar chart of weekly sales
labels = ['Mon','Tue','Wed','Thu','Fri']
values = [12, 18, 9, 14, 20]

# Your code here
plt.bar(labels, values)
for i, v in enumerate(values):
  plt.text(i, v + 0.3, str(v), ha='center')
plt.show()

# %% [markdown]
# ## Exercise 6 — Histogram
# Generate 1000 samples from a normal distribution with mean 0 and std 1.
#
# **Goals:**
# - Plot a histogram with 30 bins
# - Show density (probability) instead of counts (`density=True`)
# - Add a vertical line at the mean

# %%
# TODO: Histogram with density
samples = rng.normal(0, 1, size=1000)

# Your code here
plt.hist(samples, bins=30, density=True)
plt.axvline(samples.mean(), linestyle='--')
plt.title('Normal(0,1) Histogram')
plt.show()

# %% [markdown]
# ## Exercise 7 — Subplots
# Create a figure with **two subplots (1 row, 2 columns)**:
# - Left: `sin(x)`
# - Right: `cos(x)`
#
# **Goals:**
# - Use `plt.subplots(1, 2, figsize=(10,4))`
# - Plot on each axis separately
# - Add titles to each subplot

# %%
# TODO: Subplots of sin and cos
x = np.linspace(0, 2*np.pi, 200)
ysin = np.sin(x)
ycos = np.cos(x)

fig, axes = plt.subplots(1, 2, figsize=(10, 4))
ax1, ax2 = axes
ax1.plot(ysin); ax1.set_title('sin(x)')
ax2.plot(ycos); ax2.set_title('cos(x)')
plt.show()

# %% [markdown]
# ## Exercise 8 — Pie Chart
# Visualize category shares with a pie chart:
#
# Labels = `['A','B','C','D']`
# Sizes = `[30, 25, 20, 25]`
#
# **Goals:**
# - Use `plt.pie`
# - Add `autopct='%1.1f%%'`
# - Optionally `explode` one slice
# - Make the chart a circle using `plt.axis('equal')`

# %%
# TODO: Create a pie chart with labels and percentages
labels = ['A','B','C','D']
sizes = [30, 25, 20, 25]
explode = [0.05, 0, 0, 0]  # optional

# Your code here
plt.pie(sizes, labels=labels, autopct='%1.1f%%', explode=explode,)
plt.axis('equal')
plt.title('Category Shares')
plt.show()

# %% [markdown]
# ## Exercise 9 — Using pandas with Matplotlib
# Create a small `pandas` DataFrame of monthly temperatures and plot it.
#
# **Data:**
# ```
# Month: Jan Feb Mar Apr May Jun
# Temp:  26  28  29  30  31  32
# ```
#
# **Goals:**
# - Build the DataFrame
# - Plot a line chart of Temp vs Month using either `plt.plot` or `df.plot`
# - Label axes and rotate tick labels

# %%
# TODO: Build a DataFrame and plot Temp vs Month
months = ['Jan','Feb','Mar','Apr','May','Jun']
temps = [26, 28, 29, 30, 31, 32]

df = pd.DataFrame({"Month": months, "Temperature": temps})
plt.plot(months, temps, marker='o')
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.title("Monthly Temperatures")
plt.show()
# Option B: df.plot(x='Month', y='Temp')
plt.show()

# %% [markdown]
# ## Exercise 10 — Fill Between (Confidence Band)
# Simulate a noisy signal and a 1-σ confidence band.
#
# **Goals:**
# - Create `x` from 0 to 10 (200 points)
# - Let `y = sin(x) + noise` with noise `~ Normal(0, 0.2)`
# - Let `sigma = 0.3`
# - Plot the line and fill the area between `y - sigma` and `y + sigma` using `plt.fill_between`

# %%
# TODO: Plot a line with a confidence band using fill_between
x = np.linspace(0, 10, 200)
noise = rng.normal(0, 0.2, size=x.size)
y = np.sin(x) + noise
sigma = 0.3

# Your code here
plt.plot(x, y, label='signal')
plt.fill_between(x, y - sigma, y + sigma, alpha=0.3, label='±1σ')
plt.legend()
plt.show()

# %%
# Read CSV, parse timestamp column as datetime
df = pd.read_csv("sensor_data.csv", parse_dates=["Timestamp"])

# Show first few rows
print(df.head())

# Access temperature & humidity
temps = df["Temperature (C)"]
humidity = df["Humidity (%)"]

print("Average Temperature:", temps.mean())
print("Average Humidity:", humidity.mean())

# --- Plotting ---
plt.figure(figsize=(10,5))

# Plot temperature
plt.plot(df["Timestamp"], temps, label="Temperature (°C)", color="red")

# Plot humidity
plt.plot(df["Timestamp"], humidity, label="Humidity (%)", color="blue")

plt.xlabel("Time")
plt.ylabel("Values")
plt.title("Temperature & Humidity over Time")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#                    Timestamp  Temperature (C)  Humidity (%)
# 0 2025-08-24 16:49:20.029935             25.2          63.3
# 1 2025-08-24 16:49:23.042900             25.3          63.5
# 2 2025-08-24 16:49:26.048298             25.2          63.4
# 3 2025-08-24 16:49:29.050597             25.3          63.5
# 4 2025-08-24 16:49:32.065795             25.2          63.4
# Average Temperature: 25.0811320754717
# Average Humidity: 63.98301886792454

# %%
def comp_country(c1, c2):
    if c1[1] == c2[1]:
        return c1[2] < c2[2]
    else:
        return c1[1] < c2[1]

def comp_country(c1, c2):
    return (c1[1], c1[2]) < (c2[1], c2[2])

def qs(country_lst):
  if len(country_lst) <= 1:
    return country_lst
  pivot = country_lst[0]
  left, right = [], []
  for item in country_lst[1:]:
    if comp_country(item, pivot):
      left.append(item)
    else:
      right.append(item)
  sort_left = qs(left)
  sort_right = qs(right)
  return sort_left + [pivot] + sort_right

with open("youth_cleaned.txt", "r") as f:
  raw_data = f.read()
  rows = raw_data.split("\n")

  countries = []
  for row in rows[1:50]:
    country, code, year = row.split(",")
    if year == "":
      pass
    else:
      countries.append((country,code, year))
    sorted_countries = qs(countries)
  print(sorted_countries)
  output = ""
  for c in countries:
    output += f"{c[0]},{c[1]},{c[2]}\n"
  with open("youth_output.txt","w") as f:
    f.write(output)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3484344417.py in <cell line: 0>()
#      28   countries = []
#      29   for row in rows[1:50]:
# ---> 30     country, code, year = row.split(",")
#      31     if year == "":
#      32       pass
#
# ValueError: not enough values to unpack (expected 3, got 1)
